# %% [markdown]
# <a href="https://colab.research.google.com/github/darshandugar2004/XrayImageClassification-TransferLearning/blob/main/dataset_preperation_lungs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')
from tensorflow import keras
from keras.layers import Input, Dense, Flatten, GlobalAveragePooling2D, Dropout
from keras.models import Model
from keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Corrected import
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping
import numpy as np

# %%
import os
import shutil
import pandas as pd
import cv2
from tqdm import tqdm
import random

# dataset paths
cpn_path = "/kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset"
pn_path = "/kaggle/input/chest-xray-pneumonia/chest_xray/train"
c_path = "/kaggle/input/image-processing/train-20230326T152931Z-001/train"

# create output folders
output_base = "/kaggle/working/Cov-Pneum"
categories = ["COVID-19", "Pneumonia", "Normal"]

for category in categories:
    os.makedirs(os.path.join(output_base, category), exist_ok=True)

# function to copy and resize images
def copy_and_resize_images(src_folder, dest_folder, target_size=(224, 224)):
    for img_name in tqdm(os.listdir(src_folder), desc=f"Processing {dest_folder}"):
        img_path = os.path.join(src_folder, img_name)
        try:
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, target_size)
                cv2.imwrite(os.path.join(dest_folder, img_name), img)
        except Exception as e:
            print(f"Error processing {img_path}: {e}")


copy_and_resize_images(os.path.join(cpn_path, "COVID/images"), os.path.join(output_base, "COVID-19"))
copy_and_resize_images(os.path.join(cpn_path, "Viral Pneumonia/images"), os.path.join(output_base, "Pneumonia"))
copy_and_resize_images(os.path.join(cpn_path, "Normal/images"), os.path.join(output_base, "Normal"))
copy_and_resize_images(os.path.join(c_path, "COVID"), os.path.join(output_base, "COVID-19"))
copy_and_resize_images(os.path.join(pn_path, "PNEUMONIA"), os.path.join(output_base, "Pneumonia"))
copy_and_resize_images(os.path.join(pn_path, "NORMAL"), os.path.join(output_base, "Normal"))





split_ratios = {"train": 0.57, "validation": 0.15, "test": 0.28}
output_split_path = "/kaggle/working/Cov-Pneum-Split"


for split in split_ratios.keys():
    for category in categories:
        os.makedirs(os.path.join(output_split_path, split, category), exist_ok=True)


def split_data(category):
    images = os.listdir(os.path.join(output_base, category))
    random.shuffle(images)  # Shuffle for randomness

    train_idx = int(len(images) * split_ratios["train"])
    val_idx = train_idx + int(len(images) * split_ratios["validation"])

    for i, img_name in enumerate(images):
        src_path = os.path.join(output_base, category, img_name)

        if i < train_idx:
            dest_folder = os.path.join(output_split_path, "train", category)
        elif i < val_idx:
            dest_folder = os.path.join(output_split_path, "validation", category)
        else:
            dest_folder = os.path.join(output_split_path, "test", category)

        shutil.copy(src_path, os.path.join(dest_folder, img_name))

# Process all categories
for category in categories:
    split_data(category)

print("✅ Dataset successfully split into train, validation, and test sets!")
# Out:
# Processing /kaggle/working/Cov-Pneum/COVID-19: 100%|██████████| 3616/3616 [00:25<00:00, 144.14it/s]
# Processing /kaggle/working/Cov-Pneum/Pneumonia: 100%|██████████| 1345/1345 [00:10<00:00, 134.40it/s]
# Processing /kaggle/working/Cov-Pneum/Normal: 100%|██████████| 10192/10192 [01:11<00:00, 141.86it/s]
# Processing /kaggle/working/Cov-Pneum/COVID-19: 100%|██████████| 970/970 [00:15<00:00, 60.98it/s]
# Processing /kaggle/working/Cov-Pneum/Pneumonia: 100%|██████████| 3875/3875 [00:29<00:00, 130.46it/s]
# Processing /kaggle/working/Cov-Pneum/Normal: 100%|██████████| 1341/1341 [00:33<00:00, 40.18it/s]
# ✅ Dataset successfully split into train, validation, and test sets!

# %%
# !zip -r /kaggle/working/Cov-Pneum-Split.zip /kaggle/working/Cov-Pneum-Split
# Out:
#   adding: kaggle/working/Cov-Pneum-Split/ (stored 0%)
#   adding: kaggle/working/Cov-Pneum-Split/train/ (stored 0%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/ (stored 0%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (267).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2818.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-240.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3315.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1383.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2864.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2619.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1663.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2317.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2933.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(450).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1865.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3079.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3348.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3023.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-914.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2249.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (773).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1121.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-744.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2309.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3053.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1190.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2054.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3350.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-119.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1078.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2465.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1644.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-300.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(303).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (521).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1951.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1928.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2966.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3142.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3535.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-33.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(487).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1722.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1420.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3033.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-776.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1887.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1037.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1447.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3527.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (822).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3609.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3372.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1846.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3073.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2608.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1254.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2297.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-270.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-52.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (13).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2436.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1662.png (deflated 15%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1382.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1082.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-112.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3543.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3031.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-496.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2292.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(90).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-872.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1939.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2046.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2747.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3554.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2172.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2874.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1349.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2872.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1657.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2296.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2025.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2197.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2009.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2807.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (171).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1757.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-366.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-370.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2605.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1863.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3172.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2097.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(438).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1819.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3049.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (299).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2398.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2903.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (732).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2991.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1503.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(476).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-565.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-134.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2969.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-773.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1767.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (825).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (841).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-171.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1838.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-591.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2476.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2684.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3272.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2838.png (deflated 23%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3234.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1640.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2752.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-757.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2440.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-600.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1189.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-932.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-664.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1532.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (247).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-805.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2392.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2035.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-318.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3221.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1075.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1533.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3413.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2443.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (212).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2024.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2171.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-985.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3227.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1916.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1712.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1508.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-279.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-521.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-707.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(30).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2914.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2976.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (479).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-594.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2374.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2885.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-706.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3365.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1229.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1388.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-849.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-184.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3171.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(426).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1729.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1097.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2999.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1334.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2014.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3346.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-976.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2439.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1902.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2356.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2313.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1714.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2030.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3508.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-730.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-732.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1143.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1953.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2346.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-578.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (302).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (606).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1070.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2537.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2876.png (deflated 15%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2280.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-329.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-260.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-114.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2199.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-991.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3102.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2853.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2466.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1932.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1845.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(355).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3517.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3588.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-423.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2854.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2540.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-863.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2405.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-262.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-800.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3156.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1130.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2291.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3576.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (867).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1029.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (455).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2927.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (642).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(20).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1531.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1408.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1285.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1115.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2665.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (465).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3545.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-713.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1725.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-382.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (705).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/7D2CF6CE-F529-4470-8356-D33FFAF98600.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1667.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1411.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(223).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1848.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2185.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1567.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2784.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(400).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1480.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2543.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(173).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-837.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2219.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-750.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2909.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1840.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-734.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(118).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1030.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-241.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1182.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2676.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-791.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2303.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (203).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2007.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3104.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1709.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-536.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (341).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(203).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-641.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-828.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (315).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1751.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(471).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2649.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3301.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3531.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (692).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-467.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (188).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3614.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3562.png (deflated 22%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-781.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1684.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-375.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2804.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (131).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2250.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1611.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (756).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2154.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-997.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2182.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3004.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-687.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1252.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2118.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3481.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-387.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2114.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2987.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2977.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-396.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1584.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2740.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2520.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1527.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2227.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1606.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(183).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2449.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(507).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-485.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-410.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2519.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-311.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(432).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3419.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1231.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2371.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-769.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2142.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (156).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(164).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2842.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2738.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(123).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (266).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1406.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-459.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-616.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1336.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-642.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (275).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1050.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2770.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3012.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1127.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (110).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-10.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(512).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3424.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (870).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3312.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-116.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1344.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1392.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-213.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1759.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1119.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3305.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1347.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2324.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-508.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2596.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (741).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2897.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (426).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1215.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-161.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-675.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (645).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-336.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1491.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2067.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2823.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(305).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3520.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-488.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1964.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3323.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1393.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2130.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2028.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1402.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2553.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-615.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(304).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-666.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(52).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3452.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2127.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2115.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2101.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (546).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1797.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1225.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3492.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1175.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-928.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-84.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-897.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-353.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1281.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (679).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-871.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1718.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(557).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2613.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(296).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2413.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1526.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(239).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(403).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (767).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (744).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3067.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2086.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-911.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7-768x495.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2063.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2188.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-210.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-195.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1950.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2433.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2233.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1586.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3196.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2534.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3146.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-281.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-987.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1049.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2833.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (195).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1892.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (849).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (598).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1063.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2285.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-259.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3029.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1112.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-36.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (285).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1440.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2210.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2765.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1763.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3459.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3066.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1974.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3468.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2901.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3408.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(216).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2946.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-148.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(0).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-854.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-135.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (595).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (111).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1357.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (406).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3335.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-233.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1409.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1396.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (18).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-145.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1670.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1612.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-649.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(101).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1501.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3343.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2305.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-380.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2895.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1107.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(559).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1370.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1914.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1299.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1239.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-385.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2027.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-296.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3168.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3082.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1782.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3115.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2514.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3081.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-973.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (801).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-255.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2350.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2253.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1692.png (deflated 21%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-431.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2411.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(542).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2787.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(70).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (402).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3137.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3373.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2824.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1962.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (765).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (449).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-321.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-977.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (664).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2609.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3246.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1705.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (669).jpg (deflated 4%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2606.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1211.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2470.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3106.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3498.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-312.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1746.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2121.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2477.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2834.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-499.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1851.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(231).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(526).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(302).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(167).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-990.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (68).jpg (deflated 2%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (524).jpg (deflated 3%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1177.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2414.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1085.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(362).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2912.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-361.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(430).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3332.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2749.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-390.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(201).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1784.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2846.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1203.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2515.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-323.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1969.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2931.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2635.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2908.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(344).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(68).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-19 (675).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1695.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1512.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1274.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID19(120).jpg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1896.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-2714.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-374.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-1631.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-3290.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/train/COVID-19/COVID-966.png (deflated 17%)
# ...
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-589.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-1412-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-499.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3157.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1863.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5483.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-10091.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/IM-0736-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3504.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7607.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2462.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/IM-0253-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2069.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-453.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2556.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9064.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3216.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9754.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1289.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8652.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1485.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7925.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3702.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3751.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-356.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9194.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6991.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-0500-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-410.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6771.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5275.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8005.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7890.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6262.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2612.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8416.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-1221-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5242.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-814.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9928.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9050.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7818.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-0834-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7523.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9433.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6249.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3220.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-565.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5003.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3117.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4889.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7879.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5227.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3217.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3447.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2508.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9468.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7463.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6757.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7206.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/IM-0619-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-0879-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4945.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9842.png (deflated 15%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8749.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1635.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4377.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-1236-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6844.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8586.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5839.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-0812-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4584.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5115.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/IM-0209-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1769.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/IM-0609-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7193.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-435.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6770.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1942.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1107.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5992.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3359.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/IM-0713-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9197.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6572.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4958.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1721.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7470.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1624.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-180.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5957.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8079.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4383.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1562.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4236.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4874.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7639.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2351.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8012.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7423.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8680.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5787.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1935.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8086.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7514.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-1006-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6556.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-915.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8474.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4191.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1614.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4564.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-0466-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9428.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6516.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-0954-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6791.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-133.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4764.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6980.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2920.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1738.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6717.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9962.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-0932-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5854.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5176.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2684.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9574.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-991.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6915.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-10168.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6887.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1649.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2137.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-299.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-1054-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9279.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8779.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8815.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4003.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3282.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8269.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3043.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4935.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1217.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1273.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7561.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5643.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4435.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-10057.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4209.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3841.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6450.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/NORMAL2-IM-0900-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8785.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3865.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5871.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5173.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8770.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9966.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6978.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2592.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3740.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8236.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2250.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/IM-0739-0001.jpeg (deflated 1%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-1939.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9212.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-309.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7809.png (deflated 16%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6366.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-4061.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9423.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7830.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-2827.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-7799.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-463.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-6438.png (deflated 19%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3503.png (deflated 17%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9418.png (deflated 15%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8747.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9402.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-5525.png (deflated 20%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-8748.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-3829.png (deflated 18%)
#   adding: kaggle/working/Cov-Pneum-Split/test/Normal/Normal-9373.png
